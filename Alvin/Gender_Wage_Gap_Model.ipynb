# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
# Load the datasets
athlete_events_df = pd.read_csv('../Resources/DataFrames/Model_prep/Medals/athleteEvents_mf_model.csv')
gender_data_df = pd.read_csv('../Resources/DataFrames/Model_prep/Gender_wage_gap_model.csv')

# %%
gender_data_df
# Out:
#                             Reference area  REF_AREA  TIME_PERIOD  \
# 0                                Australia       AUS         1980
# 1                                Australia       AUS         1979
# 2                                Australia       AUS         1978
# 3                                   Brazil       BRA         2016
# 4                                   Brazil       BRA         2015
# ..                                     ...       ...          ...
# 942  European Union (19 countries) in OECD  EU19OECD         2005
# 943  European Union (19 countries) in OECD  EU19OECD         2004
# 944  European Union (19 countries) in OECD  EU19OECD         2003
# 945                                 Greece       GRC         2019
# 946                                Germany       DEU         1997
#
#      Median_%_of_men_wages_gap
# 0                    18.750000
# 1                    20.000000
# 2                    19.791667
# 3                    14.285714
# 4                    15.384615
# ..                         ...
# 942                  15.987233
# 943                  16.940374
# 944                  17.649478
# 945                   5.909091
# 946                  21.575342
#
# [947 rows x 4 columns]

# %%
athlete_events_df
# Out:
#       NOC         Team  Year Sex   Medal  Count
# 0     AFG  Afghanistan  2008   M  Bronze      1
# 1     AFG  Afghanistan  2012   M  Bronze      1
# 2     ALG      Algeria  1992   F    Gold      1
# 3     ALG      Algeria  2000   F    Gold      1
# 4     ALG      Algeria  2008   F  Bronze      1
# ...   ...          ...   ...  ..     ...    ...
# 4505  ZIM     Zimbabwe  2004   F  Bronze      1
# 4506  ZIM     Zimbabwe  2004   F    Gold      1
# 4507  ZIM     Zimbabwe  2004   F  Silver      1
# 4508  ZIM     Zimbabwe  2008   F    Gold      1
# 4509  ZIM     Zimbabwe  2008   F  Silver      3
#
# [4510 rows x 6 columns]

# %%
merged_df = pd.merge(athlete_events_df, gender_data_df, left_on=['NOC', 'Year'], right_on=['REF_AREA', 'TIME_PERIOD'], how='inner')

# %%
merged_df
# Out:
#      NOC             Team  Year Sex   Medal  Count Reference area REF_AREA  \
# 0    AUS        Australia  1980   F  Bronze      1      Australia      AUS
# 1    AUS        Australia  1980   F    Gold      1      Australia      AUS
# 2    AUS        Australia  1980   M  Bronze      4      Australia      AUS
# 3    AUS        Australia  1980   M    Gold      5      Australia      AUS
# 4    AUS        Australia  1980   M  Silver      2      Australia      AUS
# ..   ...              ...   ...  ..     ...    ...            ...      ...
# 987  USA  United States-1  2016   F  Silver      1  United States      USA
# 988  USA  United States-1  2016   M  Silver      1  United States      USA
# 989  USA  United States-2  2016   F    Gold      1  United States      USA
# 990  USA  United States-2  2016   M  Bronze      2  United States      USA
# 991  USA  United States-2  2016   M    Gold      1  United States      USA
#
#      TIME_PERIOD  Median_%_of_men_wages_gap
# 0           1980                  18.750000
# 1           1980                  18.750000
# 2           1980                  18.750000
# 3           1980                  18.750000
# 4           1980                  18.750000
# ..           ...                        ...
# 987         2016                  18.142077
# 988         2016                  18.142077
# 989         2016                  18.142077
# 990         2016                  18.142077
# 991         2016                  18.142077
#
# [992 rows x 10 columns]

# %%
medal_count_by_gender = merged_df.groupby(['NOC', 'Year', 'Sex']).agg({
    'Count': 'sum',  # Sum of medals won
    'Median_%_of_men_wages_gap': 'mean'  # Average wage gap for simplicity
}).reset_index()

# %%
medal_count_by_gender
# Out:
#      NOC  Year Sex  Count  Median_%_of_men_wages_gap
# 0    AUS  1976   M     22                  20.754717
# 1    AUS  1980   F      2                  18.750000
# 2    AUS  1980   M     11                  18.750000
# 3    AUS  1984   F     11                  18.674699
# 4    AUS  1984   M     41                  18.674699
# ..   ...   ...  ..    ...                        ...
# 380  USA  2012   M     88                  19.086651
# 381  USA  2014   F     39                  17.451206
# 382  USA  2014   M     25                  17.451206
# 383  USA  2016   F    149                  18.142077
# 384  USA  2016   M    114                  18.142077
#
# [385 rows x 5 columns]

# %%
men_df = medal_count_by_gender[medal_count_by_gender['Sex'] == 'M']
women_df = medal_count_by_gender[medal_count_by_gender['Sex'] == 'F']

# %%
correlation_men = men_df[['Count', 'Median_%_of_men_wages_gap']].corr().iloc[0, 1]
correlation_women = women_df[['Count', 'Median_%_of_men_wages_gap']].corr().iloc[0, 1]

# %%
print(f"Correlation between gender wage gap and medal count (Men): {correlation_men}")
print(f"Correlation between gender wage gap and medal count (Women): {correlation_women}")
# Out:
# Correlation between gender wage gap and medal count (Men): 0.19484673476181982
# Correlation between gender wage gap and medal count (Women): 0.08388847649617107

# %%
features = medal_count_by_gender.drop(columns=['Count', 'NOC', 'Sex', 'Year'])
target = medal_count_by_gender['Count']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Initialize the Random Forest Regressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
# Train the model
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions
y_pred = rf.predict(X_test)

# %%
# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 20.674439393939394

# %%
# Function to calculate correlation for each country and gender
def calculate_country_correlation(group):
    return group[['Count', 'Median_%_of_men_wages_gap']].corr().iloc[0, 1]

# %%
# Calculate correlation for each country and gender
country_gender_correlation = medal_count_by_gender.groupby(['NOC', 'Sex']).apply(calculate_country_correlation).reset_index()

# %%
# Rename the correlation column for clarity
country_gender_correlation = country_gender_correlation.rename(columns={0: 'Correlation'})

# %%
# Display the correlation for each country and gender
country_gender_correlation
# Out:
#     NOC Sex  Correlation
# 0   AUS   F    -0.300004
# 1   AUS   M    -0.214345
# 2   AUT   F    -0.290925
# 3   AUT   M     0.121380
# 4   BEL   F     0.419562
# 5   BEL   M    -0.695070
# 6   BRA   F     1.000000
# 7   BRA   M    -1.000000
# 8   CAN   F    -0.452400
# 9   CAN   M    -0.326202
# 10  COL   F     0.881190
# 11  COL   M     0.881190
# 12  CZE   F     0.041892
# 13  CZE   M    -0.330886
# 14  EST   F     1.000000
# 15  EST   M    -1.000000
# 16  FIN   F    -0.091046
# 17  FIN   M     0.168855
# 18  FRA   F    -0.079477
# 19  FRA   M     0.059921
# 20  GBR   F    -0.390537
# 21  GBR   M    -0.243196
# 22  HUN   F     0.649751
# 23  HUN   M     0.206315
# 24  ISR   F          NaN
# 25  ISR   M     0.992097
# 26  ITA   F     0.566692
# 27  ITA   M     0.756156
# 28  JPN   F    -0.367042
# 29  JPN   M    -0.004345
# 30  KOR   F    -0.306515
# 31  KOR   M    -0.209589
# 32  MEX   F    -0.581570
# 33  MEX   M    -0.829483
# 34  NOR   F     0.279705
# 35  NOR   M     0.395358
# 36  NZL   F    -0.367479
# 37  NZL   M     0.360369
# 38  POL   F    -0.352939
# 39  POL   M     0.699868
# 40  SVK   F    -0.393909
# 41  SVK   M     0.259871
# 42  SWE   F    -0.075862
# 43  SWE   M    -0.131997
# 44  USA   F    -0.214826
# 45  USA   M     0.250700
