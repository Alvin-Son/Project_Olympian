# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
# Load the datasets
athlete_events_df = pd.read_csv('../Resources/DataFrames/Model_prep/Medals/athleteEvents_mf_model.csv')
health_data_df = pd.read_csv('../Resources/DataFrames/Model_prep/Perceived_health_model.csv')

# %%
athlete_events_df
# Out:
#       NOC         Team  Year Sex   Medal  Count
# 0     AFG  Afghanistan  2008   M  Bronze      1
# 1     AFG  Afghanistan  2012   M  Bronze      1
# 2     ALG      Algeria  1992   F    Gold      1
# 3     ALG      Algeria  2000   F    Gold      1
# 4     ALG      Algeria  2008   F  Bronze      1
# ...   ...          ...   ...  ..     ...    ...
# 4505  ZIM     Zimbabwe  2004   F  Bronze      1
# 4506  ZIM     Zimbabwe  2004   F    Gold      1
# 4507  ZIM     Zimbabwe  2004   F  Silver      1
# 4508  ZIM     Zimbabwe  2008   F    Gold      1
# 4509  ZIM     Zimbabwe  2008   F  Silver      3
#
# [4510 rows x 6 columns]

# %%
health_data_df
# Out:
#      STRUCTURE_NAME REF_AREA Reference area  TIME_PERIOD                  Age  \
# 0     Health status      FIN        Finland         1980  From 25 to 44 years
# 1     Health status      FIN        Finland         1981  From 25 to 44 years
# 2     Health status      FIN        Finland         1982  From 25 to 44 years
# 3     Health status      FIN        Finland         1983  From 25 to 44 years
# 4     Health status      FIN        Finland         1984  From 25 to 44 years
# ...             ...      ...            ...          ...                  ...
# 1438  Health status      HRV        Croatia         2019  From 15 to 24 years
# 1439  Health status      HRV        Croatia         2020  From 15 to 24 years
# 1440  Health status      HRV        Croatia         2021  From 15 to 24 years
# 1441  Health status      HRV        Croatia         2022  From 15 to 24 years
# 1442  Health status      HRV        Croatia         2023  From 15 to 24 years
#
#       % of pop perceived
# 0                    73.5
# 1                    75.4
# 2                    74.9
# 3                    76.5
# 4                    74.4
# ...                   ...
# 1438                 95.3
# 1439                 95.8
# 1440                 95.9
# 1441                 96.1
# 1442                 96.7
#
# [1443 rows x 6 columns]

# %%
merged_df = pd.merge(athlete_events_df, health_data_df, left_on=['NOC', 'Year'], right_on=['REF_AREA', 'TIME_PERIOD'], how='inner')

# %%
merged_df
# Out:
#       NOC             Team  Year Sex   Medal  Count STRUCTURE_NAME REF_AREA  \
# 0     AUS        Australia  2004   F  Bronze     12  Health status      AUS
# 1     AUS        Australia  2004   F  Bronze     12  Health status      AUS
# 2     AUS        Australia  2004   F    Gold     18  Health status      AUS
# 3     AUS        Australia  2004   F    Gold     18  Health status      AUS
# 4     AUS        Australia  2004   F  Silver     32  Health status      AUS
# ...   ...              ...   ...  ..     ...    ...            ...      ...
# 1625  USA  United States-2  2016   F    Gold      1  Health status      USA
# 1626  USA  United States-2  2016   M  Bronze      2  Health status      USA
# 1627  USA  United States-2  2016   M  Bronze      2  Health status      USA
# 1628  USA  United States-2  2016   M    Gold      1  Health status      USA
# 1629  USA  United States-2  2016   M    Gold      1  Health status      USA
#
#      Reference area  TIME_PERIOD                  Age  % of pop perceived
# 0         Australia         2004  From 25 to 44 years                 90.0
# 1         Australia         2004  From 15 to 24 years                 93.3
# 2         Australia         2004  From 25 to 44 years                 90.0
# 3         Australia         2004  From 15 to 24 years                 93.3
# 4         Australia         2004  From 25 to 44 years                 90.0
# ...             ...          ...                  ...                  ...
# 1625  United States         2016  From 15 to 24 years                 96.1
# 1626  United States         2016  From 25 to 44 years                 93.1
# 1627  United States         2016  From 15 to 24 years                 96.1
# 1628  United States         2016  From 25 to 44 years                 93.1
# 1629  United States         2016  From 15 to 24 years                 96.1
#
# [1630 rows x 12 columns]

# %%
merged_df.columns
# Out:
# Index(['NOC', 'Team', 'Year', 'Sex', 'Medal', 'Count', 'STRUCTURE_NAME',
#        'REF_AREA', 'Reference area', 'TIME_PERIOD', 'Age',
#        '% of pop perceived '],
#       dtype='object')

# %%
# Preparing features and target
features = merged_df[['% of pop perceived ']]
target = merged_df['Count']

# %%
# Continue with splitting the data and training the model
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
# Initialize the Random Forest Regressor
rf = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
# Train the model
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions
y_pred = rf.predict(X_test)

# %%
# Evaluate the model
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 7.859775464472833

# %%
medal_counts = merged_df.pivot_table(index=['NOC', 'Year'], columns='Medal', values='Count', aggfunc='sum', fill_value=0).reset_index()

# %%
merged_df = pd.merge(medal_counts, health_data_df, left_on=['NOC', 'Year'], right_on=['REF_AREA', 'TIME_PERIOD'], how='inner')

# %%
# Analyze for each type of medal (Gold, Silver, Bronze) separately
for medal_type in ['Gold', 'Silver', 'Bronze']:
    print(f"\nAnalyzing {medal_type} Medals:")

    # Prepare the features and target
    features = merged_df[['% of pop perceived ']]  # Add other features as needed
    target = merged_df[medal_type]
    
    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
    
    # Initialize and train the model
    rf = RandomForestRegressor(n_estimators=100, random_state=42)
    rf.fit(X_train, y_train)
    
    # Make predictions
    y_pred = rf.predict(X_test)
    
    # Evaluate the model
    mae = mean_absolute_error(y_test, y_pred)
    print(f'Mean Absolute Error for {medal_type} Medals: {mae}')
# Out:
# Analyzing Gold Medals:
# Mean Absolute Error for Gold Medals: 35.321644332450305
#
# Analyzing Silver Medals:
# Mean Absolute Error for Silver Medals: 25.006487228360363
#
# Analyzing Bronze Medals:
# Mean Absolute Error for Bronze Medals: 26.959028423897827

# %%
# Analyze for each country separately
countries = merged_df['NOC'].unique()

for country in countries:
    print(f"\nAnalyzing {country}:")

    # Filter the data for the specific country
    country_df = merged_df[merged_df['NOC'] == country]
    
    if country_df.shape[0] < 2:
        print(f"Not enough data for {country} to train a model.")
        continue
    
    for medal_type in ['Gold', 'Silver', 'Bronze']:
        print(f"\nAnalyzing {medal_type} Medals for {country}:")

        # Prepare the features and target
        features = country_df[['% of pop perceived ']]  # Add other features as needed
        target = country_df[medal_type]
        
        # Split the data
        X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
        
        # Initialize and train the model
        rf = RandomForestRegressor(n_estimators=100, random_state=42)
        rf.fit(X_train, y_train)
        
        # Make predictions
        y_pred = rf.predict(X_test)
        
        # Evaluate the model
        mae = mean_absolute_error(y_test, y_pred)
        print(f'Mean Absolute Error for {medal_type} Medals in {country}: {mae}')
# Out:
# Analyzing AUS:
#
# Analyzing Gold Medals for AUS:
# Mean Absolute Error for Gold Medals in AUS: 92.12
#
# Analyzing Silver Medals for AUS:
# Mean Absolute Error for Silver Medals in AUS: 141.0
#
# Analyzing Bronze Medals for AUS:
# Mean Absolute Error for Bronze Medals in AUS: 56.4
#
# Analyzing AUT:
#
# Analyzing Gold Medals for AUT:
# Mean Absolute Error for Gold Medals in AUT: 10.993333333333332
#
# Analyzing Silver Medals for AUT:
# Mean Absolute Error for Silver Medals in AUT: 10.413333333333334
#
# Analyzing Bronze Medals for AUT:
# Mean Absolute Error for Bronze Medals in AUT: 9.666666666666666
#
# Analyzing BEL:
#
# Analyzing Gold Medals for BEL:
# Mean Absolute Error for Gold Medals in BEL: 0.97
#
# Analyzing Silver Medals for BEL:
# Mean Absolute Error for Silver Medals in BEL: 6.125
#
# Analyzing Bronze Medals for BEL:
# Mean Absolute Error for Bronze Medals in BEL: 1.83
#
# Analyzing CAN:
#
# Analyzing Gold Medals for CAN:
# Mean Absolute Error for Gold Medals in CAN: 52.46166666666666
#
# Analyzing Silver Medals for CAN:
# Mean Absolute Error for Silver Medals in CAN: 13.536333333333333
#
# Analyzing Bronze Medals for CAN:
# Mean Absolute Error for Bronze Medals in CAN: 38.121333333333325
#
# Analyzing CZE:
#
# Analyzing Gold Medals for CZE:
# Mean Absolute Error for Gold Medals in CZE: 4.319999999999999
#
# Analyzing Silver Medals for CZE:
# Mean Absolute Error for Silver Medals in CZE: 4.586666666666667
#
# Analyzing Bronze Medals for CZE:
# Mean Absolute Error for Bronze Medals in CZE: 5.006666666666667
#
# Analyzing ESP:
#
# Analyzing Gold Medals for ESP:
# Mean Absolute Error for Gold Medals in ESP: 4.609999999999999
#
# Analyzing Silver Medals for ESP:
# Mean Absolute Error for Silver Medals in ESP: 45.07
#
# Analyzing Bronze Medals for ESP:
# Mean Absolute Error for Bronze Medals in ESP: 15.010000000000002
#
# Analyzing EST:
#
# Analyzing Gold Medals for EST:
# Mean Absolute Error for Gold Medals in EST: 2.7133333333333334
#
# Analyzing Silver Medals for EST:
# Mean Absolute Error for Silver Medals in EST: 1.6600000000000001
#
# Analyzing Bronze Medals for EST:
# Mean Absolute Error for Bronze Medals in EST: 1.9866666666666666
#
# Analyzing FIN:
#
# Analyzing Gold Medals for FIN:
# Mean Absolute Error for Gold Medals in FIN: 3.5742857142857147
#
# Analyzing Silver Medals for FIN:
# Mean Absolute Error for Silver Medals in FIN: 11.265714285714285
#
# Analyzing Bronze Medals for FIN:
# Mean Absolute Error for Bronze Medals in FIN: 24.580000000000002
#
# Analyzing FRA:
#
# Analyzing Gold Medals for FRA:
# Mean Absolute Error for Gold Medals in FRA: 19.12
#
# Analyzing Silver Medals for FRA:
# Mean Absolute Error for Silver Medals in FRA: 26.64
#
# Analyzing Bronze Medals for FRA:
# Mean Absolute Error for Bronze Medals in FRA: 9.42
#
# Analyzing GBR:
#
# Analyzing Gold Medals for GBR:
# Mean Absolute Error for Gold Medals in GBR: 20.281999999999996
#
# Analyzing Silver Medals for GBR:
# Mean Absolute Error for Silver Medals in GBR: 17.022
#
# Analyzing Bronze Medals for GBR:
# Mean Absolute Error for Bronze Medals in GBR: 24.857999999999997
#
# Analyzing HUN:
#
# Analyzing Gold Medals for HUN:
# Mean Absolute Error for Gold Medals in HUN: 21.72
#
# Analyzing Silver Medals for HUN:
# Mean Absolute Error for Silver Medals in HUN: 32.91
#
# Analyzing Bronze Medals for HUN:
# Mean Absolute Error for Bronze Medals in HUN: 0.1900000000000004
#
# Analyzing IRL:
#
# Analyzing Gold Medals for IRL:
# Mean Absolute Error for Gold Medals in IRL: 1.44
#
# Analyzing Silver Medals for IRL:
# Mean Absolute Error for Silver Medals in IRL: 0.1608333333333336
#
# Analyzing Bronze Medals for IRL:
# Mean Absolute Error for Bronze Medals in IRL: 0.7966666666666677
#
# Analyzing ISL:
#
# Analyzing Gold Medals for ISL:
# Mean Absolute Error for Gold Medals in ISL: 0.0
#
# Analyzing Silver Medals for ISL:
# Mean Absolute Error for Silver Medals in ISL: 0.0
#
# Analyzing Bronze Medals for ISL:
# Mean Absolute Error for Bronze Medals in ISL: 0.0
#
# Analyzing ISR:
#
# Analyzing Gold Medals for ISR:
# Mean Absolute Error for Gold Medals in ISR: 2.0
#
# Analyzing Silver Medals for ISR:
# Mean Absolute Error for Silver Medals in ISR: 0.0
#
# Analyzing Bronze Medals for ISR:
# Mean Absolute Error for Bronze Medals in ISR: 0.9199999999999999
#
# Analyzing ITA:
#
# Analyzing Gold Medals for ITA:
# Mean Absolute Error for Gold Medals in ITA: 5.94
#
# Analyzing Silver Medals for ITA:
# Mean Absolute Error for Silver Medals in ITA: 15.67
#
# Analyzing Bronze Medals for ITA:
# Mean Absolute Error for Bronze Medals in ITA: 10.45
#
# Analyzing JPN:
#
# Analyzing Gold Medals for JPN:
# Mean Absolute Error for Gold Medals in JPN: 22.426666666666666
#
# Analyzing Silver Medals for JPN:
# Mean Absolute Error for Silver Medals in JPN: 18.18
#
# Analyzing Bronze Medals for JPN:
# Mean Absolute Error for Bronze Medals in JPN: 42.92666666666667
#
# Analyzing KOR:
#
# Analyzing Gold Medals for KOR:
# Mean Absolute Error for Gold Medals in KOR: 16.16
#
# Analyzing Silver Medals for KOR:
# Mean Absolute Error for Silver Medals in KOR: 10.446666666666665
#
# Analyzing Bronze Medals for KOR:
# Mean Absolute Error for Bronze Medals in KOR: 25.106666666666666
#
# Analyzing LTU:
#
# Analyzing Gold Medals for LTU:
# Mean Absolute Error for Gold Medals in LTU: 1.24
#
# Analyzing Silver Medals for LTU:
# Mean Absolute Error for Silver Medals in LTU: 2.0
#
# Analyzing Bronze Medals for LTU:
# Mean Absolute Error for Bronze Medals in LTU: 1.3099999999999996
#
# Analyzing MEX:
#
# Analyzing Gold Medals for MEX:
# Mean Absolute Error for Gold Medals in MEX: 0.0
#
# Analyzing Silver Medals for MEX:
# Mean Absolute Error for Silver Medals in MEX: 0.0
#
# Analyzing Bronze Medals for MEX:
# Mean Absolute Error for Bronze Medals in MEX: 0.0
#
# Analyzing NOR:
#
# Analyzing Gold Medals for NOR:
# Mean Absolute Error for Gold Medals in NOR: 10.27
#
# Analyzing Silver Medals for NOR:
# Mean Absolute Error for Silver Medals in NOR: 10.855
#
# Analyzing Bronze Medals for NOR:
# Mean Absolute Error for Bronze Medals in NOR: 5.825
#
# Analyzing NZL:
#
# Analyzing Gold Medals for NZL:
# Mean Absolute Error for Gold Medals in NZL: 5.640000000000001
#
# Analyzing Silver Medals for NZL:
# Mean Absolute Error for Silver Medals in NZL: 39.48
#
# Analyzing Bronze Medals for NZL:
# Mean Absolute Error for Bronze Medals in NZL: 18.8
#
# Analyzing POL:
#
# Analyzing Gold Medals for POL:
# Mean Absolute Error for Gold Medals in POL: 5.3133333333333335
#
# Analyzing Silver Medals for POL:
# Mean Absolute Error for Silver Medals in POL: 6.173333333333333
#
# Analyzing Bronze Medals for POL:
# Mean Absolute Error for Bronze Medals in POL: 5.473333333333333
#
# Analyzing ROU:
#
# Analyzing Gold Medals for ROU:
# Mean Absolute Error for Gold Medals in ROU: 5.58
#
# Analyzing Silver Medals for ROU:
# Mean Absolute Error for Silver Medals in ROU: 13.02
#
# Analyzing Bronze Medals for ROU:
# Mean Absolute Error for Bronze Medals in ROU: 24.18
#
# Analyzing SVK:
#
# Analyzing Gold Medals for SVK:
# Mean Absolute Error for Gold Medals in SVK: 1.843333333333333
#
# Analyzing Silver Medals for SVK:
# Mean Absolute Error for Silver Medals in SVK: 3.8433333333333337
#
# Analyzing Bronze Medals for SVK:
# Mean Absolute Error for Bronze Medals in SVK: 4.739999999999999
#
# Analyzing SWE:
#
# Analyzing Gold Medals for SWE:
# Mean Absolute Error for Gold Medals in SWE: 17.208571428571428
#
# Analyzing Silver Medals for SWE:
# Mean Absolute Error for Silver Medals in SWE: 21.814285714285713
#
# Analyzing Bronze Medals for SWE:
# Mean Absolute Error for Bronze Medals in SWE: 15.205714285714285
#
# Analyzing TUR:
#
# Analyzing Gold Medals for TUR:
# Mean Absolute Error for Gold Medals in TUR: 1.4
#
# Analyzing Silver Medals for TUR:
# Mean Absolute Error for Silver Medals in TUR: 1.4000000000000004
#
# Analyzing Bronze Medals for TUR:
# Mean Absolute Error for Bronze Medals in TUR: 2.2
#
# Analyzing USA:
#
# Analyzing Gold Medals for USA:
# Mean Absolute Error for Gold Medals in USA: 155.7702857142857
#
# Analyzing Silver Medals for USA:
# Mean Absolute Error for Silver Medals in USA: 36.1749126984127
#
# Analyzing Bronze Medals for USA:
# Mean Absolute Error for Bronze Medals in USA: 55.65402380952381
